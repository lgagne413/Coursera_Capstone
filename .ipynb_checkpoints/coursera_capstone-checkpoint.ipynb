# %% [markdown]
# # Coursera Capstone

# %% [markdown]
# This notebook will be primarily used for the Coursera IBM Data Science Specialization Capstone Project

# %%
#!conda install -c conda-forge xmltodict --yes
#!conda install -c conda-forge folium=0.5.0 --yes

# %%
import pandas as pd
import numpy as np
import requests
import json
import xmltodict
import folium
import matplotlib.pyplot as mpl

print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ## API Credentials

# %%
CLIENT_ID = '3B3T4ZAT2ADVQ15YL0QJ3H2DUFNYLBQ3W4J4KJWI5WDVG0PE' # your Foursquare ID
CLIENT_SECRET = 'YGXJYCHEJ410LTZKYP5FGQF4C1GQTOBTGMP0EJC1YTINVTSF' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30

zid = "X1-ZWz1hiqecilyq3_1mzvh" #zillow id

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3B3T4ZAT2ADVQ15YL0QJ3H2DUFNYLBQ3W4J4KJWI5WDVG0PE
# CLIENT_SECRET:YGXJYCHEJ410LTZKYP5FGQF4C1GQTOBTGMP0EJC1YTINVTSF

# %% [markdown]
# # Access Zillow API for neighborhood, latitude, longitude, and median home value information

# %%
zurl = "http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id={}&state=oh&city=cleveland&childtype=neighborhood".format(zid)
print(zurl)
results = xmltodict.parse(requests.get(zurl).content)
print(type(results))
# Out:
# http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz1hiqecilyq3_1mzvh&state=oh&city=cleveland&childtype=neighborhood
# <class 'collections.OrderedDict'>

# %%
neigh = results['RegionChildren:regionchildren']['response']['list']['region']
neigh[0]
# Out:
# OrderedDict([('id', '271026'),
#              ('name', 'Old Brooklyn'),
#              ('zindex',
#               OrderedDict([('@currency', 'USD'), ('#text', '67200')])),
#              ('url',
#               'http://www.zillow.com/local-info/OH-Cleveland/Old-Brooklyn/r_271026/'),
#              ('latitude', '41.434653'),
#              ('longitude', '-81.699439')])

# %% [markdown]
# Neighborhoods without median home value info could not be included.

# %%
zdf = pd.DataFrame(columns = ['Neighborhood','Median Home Value','Latitude','Longitude'])
i=0
for n in neigh:
    try:
        (n['zindex'])
        zdf.loc[i] = [n['name'],n['zindex']['#text'],n['latitude'],n['longitude']]
        i+=1
    except:
        print("{} has no zindex and so was not included".format(n['name']))
    
zdf = zdf.sort_values(by='Neighborhood').reset_index(drop=True)   
zdf.head()
# Out:
# University District has no zindex and so was not included
# St. Claire-Superior has no zindex and so was not included
# Goodrich-Kirkland Park has no zindex and so was not included
# Industrial Valley has no zindex and so was not included
# Cuyahoga Valley has no zindex and so was not included
#       Neighborhood Median Home Value   Latitude   Longitude
# 0  Brooklyn Centre             45000  41.455409  -81.700073
# 1   Buckeye Shaker             68100  41.482862  -81.593843
# 2          Central             97700  41.493157  -81.657598
# 3     Clark Fulton             41100  41.468027  -81.706737
# 4          Corlett             41700  41.445973  -81.587938

# %%
zdf['Median Home Value'] = pd.to_numeric(zdf['Median Home Value'])
zdf['Latitude'] = pd.to_numeric(zdf['Latitude'])
zdf['Longitude'] = pd.to_numeric(zdf['Longitude'])

zdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
# Neighborhood         32 non-null object
# Median Home Value    32 non-null int64
# Latitude             32 non-null float64
# Longitude            32 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# ## Visualize Neighborhoods from Zillow API

# %%
clell = [41.4993, -81.6944]
map_cle = folium.Map(location=clell, zoom_start=11)

for lat, lng, label in zip(zdf['Latitude'], zdf['Longitude'], zdf['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cle)

# %%
map_cle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Get venue information from Foursquare API

# %%
furl = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, zdf["Latitude"][0], zdf["Longitude"][0], VERSION, 1000, 20)
fresults = requests.get(furl).json()
fresults=fresults['response']['groups'][0]['items']
fresults[1]['venue']
# Out:
# {'id': '4c1b647db9f876b0e0197a46',
#  'name': "Steve's Doghouse",
#  'location': {'address': '3850 Pearl Rd',
#   'lat': 41.45018224767098,
#   'lng': -81.7019917137751,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 41.45018224767098,
#     'lng': -81.7019917137751}],
#   'distance': 603,
#   'postalCode': '44109',
#   'cc': 'US',
#   'city': 'Cleveland',
#   'state': 'OH',
#   'country': 'United States',
#   'formattedAddress': ['3850 Pearl Rd',
#    'Cleveland, OH 44109',
#    'United States']},
#  'categories': [{'id': '4bf58dd8d48988d147941735',
#    'name': 'Diner',
#    'pluralName': 'Diners',
#    'shortName': 'Diner',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#     'suffix': '.png'},
#    'primary': True}],
#  'photos': {'count': 0, 'groups': []},
#  'venuePage': {'id': '413996511'}}

# %%
venuesdf = pd.DataFrame(columns = ["Neighbourhood","Name","Category","vlat",'vlong'])
radius = 2000
lim=100
count=0
for ix in range(zdf.shape[0]):
    
    [neigh,mhv,nlat,nlong] = zdf.loc[ix]
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, nlat, nlong, VERSION, radius, lim)
    results = requests.get(url).json()['response']['groups'][0]['items']
    for venue in results:
        temp = venue['venue']
        venuesdf.loc[count]=[neigh,temp['name'],temp['categories'][0]['name'],temp['location']['lat'],temp['location']['lng']]
        count+=1
venuesdf.head()
# Out:
#      Neighbourhood                      Name             Category       vlat  \
# 0  Brooklyn Centre              CVS pharmacy             Pharmacy  41.453403
# 1  Brooklyn Centre            The RainForest          Zoo Exhibit  41.446894
# 2  Brooklyn Centre  Cleveland Metroparks Zoo                  Zoo  41.446474
# 3  Brooklyn Centre          Steve's Doghouse                Diner  41.450182
# 4  Brooklyn Centre                 Guthrie's  Fried Chicken Joint  41.460074
#
#        vlong
# 0 -81.702238
# 1 -81.709723
# 2 -81.712360
# 3 -81.701992
# 4 -81.690424

# %% [markdown]
# One hot encoding for venue dataframe

# %%
venuesdf2 = pd.get_dummies(venuesdf['Category'], prefix="", prefix_sep="")
venuesdf2['Neighborhood'] = venuesdf.Neighbourhood
cols = venuesdf2.columns.tolist()
cols.reverse()
venuesdf3 = venuesdf2[cols]
venuesdf3.shape
venuesdf3.groupby('Neighborhood').count().reset_index()
# Out:
#         Neighborhood  Zoo Exhibit  Zoo  Yoga Studio  Women's Store  \
# 0    Brooklyn Centre          100  100          100            100
# 1     Buckeye Shaker           63   63           63             63
# 2            Central           58   58           58             58
# 3       Clark Fulton          100  100          100            100
# 4            Corlett           25   25           25             25
# 5             Cudell           89   89           89             89
# 6   Detroit Shoreway           78   78           78             78
# 7           Downtown          100  100          100            100
# 8          Edgewater           48   48           48             48
# 9       Euclid Green           23   23           23             23
# 10           Fairfax           42   42           42             42
# 11      Forest Hills           42   42           42             42
# 12         Glenville           43   43           43             43
# 13             Hough           87   87           87             87
# 14         Jefferson           86   86           86             86
# 15     Kamm's Corner           73   73           73             73
# 16           Kinsman           39   39           39             39
# 17         Lee Miles           34   34           34             34
# 18       Mt Pleasant           38   38           38             38
# 19    North Broadway           33   33           33             33
# 20  North Collinwood           43   43           43             43
# 21         Ohio City          100  100          100            100
# 22      Old Brooklyn           96   96           96             96
# 23  Puritas-Longmead           40   40           40             40
# 24         Riverside           61   61           61             61
# 25    South Broadway           38   38           38             38
# 26  South Collinwood           47   47           47             47
# 27        Stockyards           48   48           48             48
# 28           Tremont          100  100          100            100
# 29  Union Miles Park           31   31           31             31
# 30    West Boulevard           52   52           52             52
# 31    Woodland Hills           56   56           56             56
#
#     Wings Joint  Wine Bar  Volleyball Court  Vietnamese Restaurant  \
# 0           100       100               100                    100
# 1            63        63                63                     63
# 2            58        58                58                     58
# 3           100       100               100                    100
# 4            25        25                25                     25
# 5            89        89                89                     89
# 6            78        78                78                     78
# 7           100       100               100                    100
# 8            48        48                48                     48
# 9            23        23                23                     23
# 10           42        42                42                     42
# 11           42        42                42                     42
# 12           43        43                43                     43
# 13           87        87                87                     87
# 14           86        86                86                     86
# 15           73        73                73                     73
# 16           39        39                39                     39
# 17           34        34                34                     34
# 18           38        38                38                     38
# 19           33        33                33                     33
# 20           43        43                43                     43
# 21          100       100               100                    100
# 22           96        96                96                     96
# 23           40        40                40                     40
# 24           61        61                61                     61
# 25           38        38                38                     38
# 26           47        47                47                     47
# 27           48        48                48                     48
# 28          100       100               100                    100
# 29           31        31                31                     31
# 30           52        52                52                     52
# 31           56        56                56                     56
#
#     Video Store  ...  Arcade  Antique Shop  Amphitheater  American Restaurant  \
# 0           100  ...     100           100           100                  100
# 1            63  ...      63            63            63                   63
# 2            58  ...      58            58            58                   58
# 3           100  ...     100           100           100                  100
# 4            25  ...      25            25            25                   25
# 5            89  ...      89            89            89                   89
# 6            78  ...      78            78            78                   78
# 7           100  ...     100           100           100                  100
# 8            48  ...      48            48            48                   48
# 9            23  ...      23            23            23                   23
# 10           42  ...      42            42            42                   42
# 11           42  ...      42            42            42                   42
# 12           43  ...      43            43            43                   43
# 13           87  ...      87            87            87                   87
# 14           86  ...      86            86            86                   86
# 15           73  ...      73            73            73                   73
# 16           39  ...      39            39            39                   39
# 17           34  ...      34            34            34                   34
# 18           38  ...      38            38            38                   38
# 19           33  ...      33            33            33                   33
# 20           43  ...      43            43            43                   43
# 21          100  ...     100           100           100                  100
# 22           96  ...      96            96            96                   96
# 23           40  ...      40            40            40                   40
# 24           61  ...      61            61            61                   61
# 25           38  ...      38            38            38                   38
# 26           47  ...      47            47            47                   47
# 27           48  ...      48            48            48                   48
# 28          100  ...     100           100           100                  100
# 29           31  ...      31            31            31                   31
# 30           52  ...      52            52            52                   52
# 31           56  ...      56            56            56                   56
#
#     Airport Terminal  Airport Service  Airport Lounge  Airport Food Court  \
# 0                100              100             100                 100
# 1                 63               63              63                  63
# 2                 58               58              58                  58
# 3                100              100             100                 100
# 4                 25               25              25                  25
# 5                 89               89              89                  89
# 6                 78               78              78                  78
# 7                100              100             100                 100
# 8                 48               48              48                  48
# 9                 23               23              23                  23
# 10                42               42              42                  42
# 11                42               42              42                  42
# 12                43               43              43                  43
# 13                87               87              87                  87
# 14                86               86              86                  86
# 15                73               73              73                  73
# 16                39               39              39                  39
# 17                34               34              34                  34
# 18                38               38              38                  38
# 19                33               33              33                  33
# 20                43               43              43                  43
# 21               100              100             100                 100
# 22                96               96              96                  96
# 23                40               40              40                  40
# 24                61               61              61                  61
# 25                38               38              38                  38
# 26                47               47              47                  47
# 27                48               48              48                  48
# 28               100              100             100                 100
# 29                31               31              31                  31
# 30                52               52              52                  52
# 31                56               56              56                  56
#
#     Airport  ATM
# 0       100  100
# 1        63   63
# 2        58   58
# 3       100  100
# 4        25   25
# 5        89   89
# 6        78   78
# 7       100  100
# 8        48   48
# 9        23   23
# 10       42   42
# 11       42   42
# 12       43   43
# 13       87   87
# 14       86   86
# 15       73   73
# 16       39   39
# 17       34   34
# 18       38   38
# 19       33   33
# 20       43   43
# 21      100  100
# 22       96   96
# 23       40   40
# 24       61   61
# 25       38   38
# 26       47   47
# 27       48   48
# 28      100  100
# 29       31   31
# 30       52   52
# 31       56   56
#
# [32 rows x 239 columns]

# %% [markdown]
# # Grouping dataframes by Neighborhood

# %% [markdown]
# We can group by the sum or mean of the categories for each neighborhood.  Grouping by sum finds neighborhoods which are identical.  Grouping by mean finds neighborhoods with similar frequencies of venues.

# %%
andfmean = venuesdf3.groupby('Neighborhood').mean().reset_index()
andfsum = venuesdf3.groupby('Neighborhood').sum().reset_index()
zdf2=zdf.sort_values(by='Neighborhood')
zdf2.head()
# Out:
#       Neighborhood  Median Home Value   Latitude  Longitude
# 0  Brooklyn Centre              45000  41.455409 -81.700073
# 1   Buckeye Shaker              68100  41.482862 -81.593843
# 2          Central              97700  41.493157 -81.657598
# 3     Clark Fulton              41100  41.468027 -81.706737
# 4          Corlett              41700  41.445973 -81.587938

# %% [markdown]
# ## Top Five Dataframe

# %% [markdown]
# Creating the following 'Top Five' dataframe helps to visualize what makes each neighborhood unique.

# %%
rankedf = pd.DataFrame(columns = ['Neighborhood','First','Second','Third','Fourth','Fifth'])
for ix in range(andfmean.shape[0]):
    a=andfmean.iloc[ix][1:-1].astype('float').nlargest()
    a=[x if y!=0 else "None" for x,y in a.items()]
    rankedf.loc[ix] = [andfmean['Neighborhood'][ix],a[0],a[1],a[2],a[3],a[4]]
rankedf
# Out:
#         Neighborhood                 First                Second  \
# 0    Brooklyn Centre           Zoo Exhibit        Sandwich Place
# 1     Buckeye Shaker        Discount Store    Light Rail Station
# 2            Central        Sandwich Place           Pizza Place
# 3       Clark Fulton        Sandwich Place               Brewery
# 4            Corlett        Sandwich Place              Pharmacy
# 5             Cudell           Pizza Place        Sandwich Place
# 6   Detroit Shoreway                   Bar        Sandwich Place
# 7           Downtown           Coffee Shop                 Hotel
# 8          Edgewater                 Diner        Sandwich Place
# 9       Euclid Green        Sandwich Place         Grocery Store
# 10           Fairfax        Sandwich Place            Restaurant
# 11      Forest Hills  Fast Food Restaurant         Grocery Store
# 12         Glenville                Garden     Convenience Store
# 13             Hough                Garden              Pharmacy
# 14         Jefferson                  Park        Sandwich Place
# 15     Kamm's Corner                   Bar   American Restaurant
# 16           Kinsman    Light Rail Station  Fast Food Restaurant
# 17         Lee Miles  Fast Food Restaurant    Seafood Restaurant
# 18       Mt Pleasant        Discount Store              Pharmacy
# 19    North Broadway  Fast Food Restaurant        Sandwich Place
# 20  North Collinwood                   Bar        Sandwich Place
# 21         Ohio City                   Bar               Brewery
# 22      Old Brooklyn           Zoo Exhibit                   Bar
# 23  Puritas-Longmead              Pharmacy        Discount Store
# 24         Riverside       Airport Service   Rental Car Location
# 25    South Broadway        Sandwich Place              Pharmacy
# 26  South Collinwood        Sandwich Place        Discount Store
# 27        Stockyards           Zoo Exhibit     Convenience Store
# 28           Tremont        Sandwich Place                   Pub
# 29  Union Miles Park        Discount Store              Pharmacy
# 30    West Boulevard        Discount Store      Department Store
# 31    Woodland Hills        Discount Store                  Bank
#
#                    Third                  Fourth                    Fifth
# 0               Pharmacy             Pizza Place                 Dive Bar
# 1                   Bank          Sandwich Place      American Restaurant
# 2          Grocery Store    Fast Food Restaurant              Gas Station
# 3            Pizza Place                Pharmacy                     Park
# 4            Gas Station    Fast Food Restaurant           Discount Store
# 5               Pharmacy      Mexican Restaurant            Grocery Store
# 6            Pizza Place              Food Truck                    Diner
# 7                Theater     American Restaurant               Steakhouse
# 8     Mexican Restaurant                Pharmacy            Grocery Store
# 9            Gas Station          Discount Store              Wings Joint
# 10    Light Rail Station                   Hotel                 Pharmacy
# 11        Discount Store               BBQ Joint           Sandwich Place
# 12             BBQ Joint                    Park     Fast Food Restaurant
# 13                 Hotel           Grocery Store     Fast Food Restaurant
# 14  Fast Food Restaurant             Video Store              Pizza Place
# 15           Video Store          Sandwich Place  New American Restaurant
# 16        Discount Store              Restaurant              Pizza Place
# 17              Pharmacy             Gas Station           Discount Store
# 18    Light Rail Station           Grocery Store                     Park
# 19           Pizza Place      Light Rail Station             Intersection
# 20            Restaurant             Record Shop              Pizza Place
# 21           Coffee Shop               Gastropub  New American Restaurant
# 22        Sandwich Place                   Diner        Convenience Store
# 23     Convenience Store          Sandwich Place      Rental Car Location
# 24        Sandwich Place                   Hotel              Coffee Shop
# 25        Discount Store           Grocery Store     Fast Food Restaurant
# 26           Pizza Place             Gas Station                      Bar
# 27        Sandwich Place                Dive Bar           Discount Store
# 28           Coffee Shop             Pizza Place                      Bar
# 29         Deli / Bodega  Thrift / Vintage Store                     Park
# 30           Pizza Place          Sandwich Place                 Pharmacy
# 31        Sandwich Place                Pharmacy      American Restaurant

# %%
zdf2=zdf.sort_values(by='Neighborhood')
zdf2.reset_index()
rankedf['Median Home Value'] = zdf2['Median Home Value']
rankedf.head()
# Out:
#       Neighborhood           First              Second          Third  \
# 0  Brooklyn Centre     Zoo Exhibit      Sandwich Place       Pharmacy
# 1   Buckeye Shaker  Discount Store  Light Rail Station           Bank
# 2          Central  Sandwich Place         Pizza Place  Grocery Store
# 3     Clark Fulton  Sandwich Place             Brewery    Pizza Place
# 4          Corlett  Sandwich Place            Pharmacy    Gas Station
#
#                  Fourth                Fifth  Median Home Value
# 0           Pizza Place             Dive Bar              45000
# 1        Sandwich Place  American Restaurant              68100
# 2  Fast Food Restaurant          Gas Station              97700
# 3              Pharmacy                 Park              41100
# 4  Fast Food Restaurant       Discount Store              41700

# %% [markdown]
# ## Data Analysis / Machine Learning

# %% [markdown]
# The first approach was to use K Means clustering to group neighborhoods by venue frequency or sum.

# %%
from sklearn.cluster import KMeans
andfmean2 = andfmean.drop('Neighborhood',1)
#andfmean2 = andfmean2.drop('Median Home Values',1)
andfmean2.head()
andfsum2 = andfsum.drop('Neighborhood',1)

# %% [markdown]
# Finding 'elbow point' for optimal k (number of clusters).  Frequency / mean had an optimal k of 4 (or 7).  Sum grouping had an optimal k of 5.

# %%
runner = andfsum2
err = []
for k in range(3,8):
    kmmodel = KMeans(n_clusters = k, random_state = 0 ).fit(runner)
    err.append(kmmodel.inertia_)
print(err)
mpl.plot(range(3,8),err)
# Out:
# [2036.3695652173915, 1811.4046345811053, 1632.7142857142856, 1527.974358974359, 1364.6140350877192]

# %%
k=5
kmmodel = KMeans(n_clusters = k, random_state = 0 ).fit(runner)
print("Error: " + str(kmmodel.inertia_))
# Out:
# Error: 1632.7142857142856

# %%
labels = kmmodel.labels_
finaldf=rankedf.drop('Median Home Value',1)
rankedf.head()
finaldf.insert(0,'Cluster',labels)
finaldf.head()
finaldf = finaldf.join(zdf2.set_index('Neighborhood'),on='Neighborhood')
finaldf
# Out:
#     Cluster      Neighborhood                 First                Second  \
# 0         2   Brooklyn Centre           Zoo Exhibit        Sandwich Place
# 1         0    Buckeye Shaker        Discount Store    Light Rail Station
# 2         0           Central        Sandwich Place           Pizza Place
# 3         1      Clark Fulton        Sandwich Place               Brewery
# 4         0           Corlett        Sandwich Place              Pharmacy
# 5         1            Cudell           Pizza Place        Sandwich Place
# 6         1  Detroit Shoreway                   Bar        Sandwich Place
# 7         4          Downtown           Coffee Shop                 Hotel
# 8         1         Edgewater                 Diner        Sandwich Place
# 9         0      Euclid Green        Sandwich Place         Grocery Store
# 10        0           Fairfax        Sandwich Place            Restaurant
# 11        0      Forest Hills  Fast Food Restaurant         Grocery Store
# 12        0         Glenville                Garden     Convenience Store
# 13        0             Hough                Garden              Pharmacy
# 14        0         Jefferson                  Park        Sandwich Place
# 15        1     Kamm's Corner                   Bar   American Restaurant
# 16        0           Kinsman    Light Rail Station  Fast Food Restaurant
# 17        0         Lee Miles  Fast Food Restaurant    Seafood Restaurant
# 18        0       Mt Pleasant        Discount Store              Pharmacy
# 19        0    North Broadway  Fast Food Restaurant        Sandwich Place
# 20        0  North Collinwood                   Bar        Sandwich Place
# 21        3         Ohio City                   Bar               Brewery
# 22        2      Old Brooklyn           Zoo Exhibit                   Bar
# 23        0  Puritas-Longmead              Pharmacy        Discount Store
# 24        0         Riverside       Airport Service   Rental Car Location
# 25        0    South Broadway        Sandwich Place              Pharmacy
# 26        0  South Collinwood        Sandwich Place        Discount Store
# 27        2        Stockyards           Zoo Exhibit     Convenience Store
# 28        1           Tremont        Sandwich Place                   Pub
# 29        0  Union Miles Park        Discount Store              Pharmacy
# 30        0    West Boulevard        Discount Store      Department Store
# 31        0    Woodland Hills        Discount Store                  Bank
#
#                    Third                  Fourth                    Fifth  \
# 0               Pharmacy             Pizza Place                 Dive Bar
# 1                   Bank          Sandwich Place      American Restaurant
# 2          Grocery Store    Fast Food Restaurant              Gas Station
# 3            Pizza Place                Pharmacy                     Park
# 4            Gas Station    Fast Food Restaurant           Discount Store
# 5               Pharmacy      Mexican Restaurant            Grocery Store
# 6            Pizza Place              Food Truck                    Diner
# 7                Theater     American Restaurant               Steakhouse
# 8     Mexican Restaurant                Pharmacy            Grocery Store
# 9            Gas Station          Discount Store              Wings Joint
# 10    Light Rail Station                   Hotel                 Pharmacy
# 11        Discount Store               BBQ Joint           Sandwich Place
# 12             BBQ Joint                    Park     Fast Food Restaurant
# 13                 Hotel           Grocery Store     Fast Food Restaurant
# 14  Fast Food Restaurant             Video Store              Pizza Place
# 15           Video Store          Sandwich Place  New American Restaurant
# 16        Discount Store              Restaurant              Pizza Place
# 17              Pharmacy             Gas Station           Discount Store
# 18    Light Rail Station           Grocery Store                     Park
# 19           Pizza Place      Light Rail Station             Intersection
# 20            Restaurant             Record Shop              Pizza Place
# 21           Coffee Shop               Gastropub  New American Restaurant
# 22        Sandwich Place                   Diner        Convenience Store
# 23     Convenience Store          Sandwich Place      Rental Car Location
# 24        Sandwich Place                   Hotel              Coffee Shop
# 25        Discount Store           Grocery Store     Fast Food Restaurant
# 26           Pizza Place             Gas Station                      Bar
# 27        Sandwich Place                Dive Bar           Discount Store
# 28           Coffee Shop             Pizza Place                      Bar
# 29         Deli / Bodega  Thrift / Vintage Store                     Park
# 30           Pizza Place          Sandwich Place                 Pharmacy
# 31        Sandwich Place                Pharmacy      American Restaurant
#
#     Median Home Value   Latitude  Longitude
# 0               45000  41.455409 -81.700073
# 1               68100  41.482862 -81.593843
# 2               97700  41.493157 -81.657598
# 3               41100  41.468027 -81.706737
# 4               41700  41.445973 -81.587938
# 5               47000  41.471245 -81.755378
# 6               64400  41.482508 -81.734843
# 7               84900  41.510191 -81.686273
# 8              103500  41.483782 -81.756003
# 9               46800  41.553378 -81.550475
# 10              58200  41.496114 -81.627204
# 11              40200  41.539191 -81.599739
# 12              44200  41.533296 -81.618464
# 13              66300  41.513143 -81.633589
# 14              58700  41.456077 -81.787534
# 15             102600  41.452172 -81.813446
# 16              43300  41.474573 -81.633190
# 17              56800  41.440951 -81.563463
# 18              42000  41.462914 -81.590287
# 19              36600  41.472583 -81.649328
# 20              55500  41.577559 -81.565047
# 21              86000  41.484848 -81.711744
# 22              67200  41.434653 -81.699439
# 23              53300  41.431929 -81.799845
# 24              82700  41.414296 -81.850750
# 25              41500  41.451918 -81.649576
# 26              42500  41.562306 -81.563538
# 27              36200  41.460289 -81.729924
# 28              75800  41.471892 -81.685040
# 29              39100  41.455690 -81.616258
# 30              54500  41.458629 -81.749600
# 31              45400  41.480805 -81.611831

# %% [markdown]
# An initial exploration of distribution of median home values after clustering by venues.

# %%
finaldf.groupby('Cluster').mean()
# Out:
#          Median Home Value   Latitude  Longitude
# Cluster
# 0             53100.000000  41.485588 -81.642814
# 1             72400.000000  41.471604 -81.741908
# 2             49466.666667  41.450117 -81.709812
# 3             86000.000000  41.484848 -81.711744
# 4             84900.000000  41.510191 -81.686273

# %% [markdown]
# ## Visualization of Clusters

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=clell, zoom_start=11)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(finaldf['Latitude'], finaldf['Longitude'], finaldf['Neighborhood'], finaldf['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Final analysis of clusters

# %% [markdown]
# The clusters are split into individual dataframes to be examined.  Also, a value range of one standard deviation above and below the mean to help identify any correlation between cluster and median home value.

# %%
valuerange=[]
def find_value_range(m,s):
    b = str(m-s)
    t=str(m+s)
    out = b + " - " + t
    print(out, m,s)
    return out
for n in range(k):
    m=int(finaldf[finaldf['Cluster']==n]['Median Home Value'].mean())
    try:
        s=int(finaldf[finaldf['Cluster']==n]['Median Home Value'].std())        
    except:
        s=0
    valuerange.append(find_value_range(m,s))
# Out:
# 37686 - 68514 53100 15414
# 45644 - 99156 72400 26756
# 33491 - 65441 49466 15975
# 86000 - 86000 86000 0
# 84900 - 84900 84900 0

# %%
n=0
print(valuerange[n])
a=finaldf[finaldf['Cluster']==n]
print(a.shape)
a
# Out:
# 37686 - 68514
# (21, 10)
#     Cluster      Neighborhood                 First                Second  \
# 1         0    Buckeye Shaker        Discount Store    Light Rail Station
# 2         0           Central        Sandwich Place           Pizza Place
# 4         0           Corlett        Sandwich Place              Pharmacy
# 9         0      Euclid Green        Sandwich Place         Grocery Store
# 10        0           Fairfax        Sandwich Place            Restaurant
# 11        0      Forest Hills  Fast Food Restaurant         Grocery Store
# 12        0         Glenville                Garden     Convenience Store
# 13        0             Hough                Garden              Pharmacy
# 14        0         Jefferson                  Park        Sandwich Place
# 16        0           Kinsman    Light Rail Station  Fast Food Restaurant
# 17        0         Lee Miles  Fast Food Restaurant    Seafood Restaurant
# 18        0       Mt Pleasant        Discount Store              Pharmacy
# 19        0    North Broadway  Fast Food Restaurant        Sandwich Place
# 20        0  North Collinwood                   Bar        Sandwich Place
# 23        0  Puritas-Longmead              Pharmacy        Discount Store
# 24        0         Riverside       Airport Service   Rental Car Location
# 25        0    South Broadway        Sandwich Place              Pharmacy
# 26        0  South Collinwood        Sandwich Place        Discount Store
# 29        0  Union Miles Park        Discount Store              Pharmacy
# 30        0    West Boulevard        Discount Store      Department Store
# 31        0    Woodland Hills        Discount Store                  Bank
#
#                    Third                  Fourth                 Fifth  \
# 1                   Bank          Sandwich Place   American Restaurant
# 2          Grocery Store    Fast Food Restaurant           Gas Station
# 4            Gas Station    Fast Food Restaurant        Discount Store
# 9            Gas Station          Discount Store           Wings Joint
# 10    Light Rail Station                   Hotel              Pharmacy
# 11        Discount Store               BBQ Joint        Sandwich Place
# 12             BBQ Joint                    Park  Fast Food Restaurant
# 13                 Hotel           Grocery Store  Fast Food Restaurant
# 14  Fast Food Restaurant             Video Store           Pizza Place
# 16        Discount Store              Restaurant           Pizza Place
# 17              Pharmacy             Gas Station        Discount Store
# 18    Light Rail Station           Grocery Store                  Park
# 19           Pizza Place      Light Rail Station          Intersection
# 20            Restaurant             Record Shop           Pizza Place
# 23     Convenience Store          Sandwich Place   Rental Car Location
# 24        Sandwich Place                   Hotel           Coffee Shop
# 25        Discount Store           Grocery Store  Fast Food Restaurant
# 26           Pizza Place             Gas Station                   Bar
# 29         Deli / Bodega  Thrift / Vintage Store                  Park
# 30           Pizza Place          Sandwich Place              Pharmacy
# 31        Sandwich Place                Pharmacy   American Restaurant
#
#     Median Home Value   Latitude  Longitude
# 1               68100  41.482862 -81.593843
# 2               97700  41.493157 -81.657598
# 4               41700  41.445973 -81.587938
# 9               46800  41.553378 -81.550475
# 10              58200  41.496114 -81.627204
# 11              40200  41.539191 -81.599739
# 12              44200  41.533296 -81.618464
# 13              66300  41.513143 -81.633589
# 14              58700  41.456077 -81.787534
# 16              43300  41.474573 -81.633190
# 17              56800  41.440951 -81.563463
# 18              42000  41.462914 -81.590287
# 19              36600  41.472583 -81.649328
# 20              55500  41.577559 -81.565047
# 23              53300  41.431929 -81.799845
# 24              82700  41.414296 -81.850750
# 25              41500  41.451918 -81.649576
# 26              42500  41.562306 -81.563538
# 29              39100  41.455690 -81.616258
# 30              54500  41.458629 -81.749600
# 31              45400  41.480805 -81.611831

# %%
n=1
print(valuerange[n])
a=finaldf[finaldf['Cluster']==n]
print(a.shape)
a
# Out:
# 45644 - 99156
# (6, 10)
#     Cluster      Neighborhood           First               Second  \
# 3         1      Clark Fulton  Sandwich Place              Brewery
# 5         1            Cudell     Pizza Place       Sandwich Place
# 6         1  Detroit Shoreway             Bar       Sandwich Place
# 8         1         Edgewater           Diner       Sandwich Place
# 15        1     Kamm's Corner             Bar  American Restaurant
# 28        1           Tremont  Sandwich Place                  Pub
#
#                  Third              Fourth                    Fifth  \
# 3          Pizza Place            Pharmacy                     Park
# 5             Pharmacy  Mexican Restaurant            Grocery Store
# 6          Pizza Place          Food Truck                    Diner
# 8   Mexican Restaurant            Pharmacy            Grocery Store
# 15         Video Store      Sandwich Place  New American Restaurant
# 28         Coffee Shop         Pizza Place                      Bar
#
#     Median Home Value   Latitude  Longitude
# 3               41100  41.468027 -81.706737
# 5               47000  41.471245 -81.755378
# 6               64400  41.482508 -81.734843
# 8              103500  41.483782 -81.756003
# 15             102600  41.452172 -81.813446
# 28              75800  41.471892 -81.685040

# %%
n=2
print(valuerange[n])
a= finaldf[finaldf['Cluster']==n]
print(a.shape)
a
# Out:
# 33491 - 65441
# (3, 10)
#     Cluster     Neighborhood        First             Second           Third  \
# 0         2  Brooklyn Centre  Zoo Exhibit     Sandwich Place        Pharmacy
# 22        2     Old Brooklyn  Zoo Exhibit                Bar  Sandwich Place
# 27        2       Stockyards  Zoo Exhibit  Convenience Store  Sandwich Place
#
#          Fourth              Fifth  Median Home Value   Latitude  Longitude
# 0   Pizza Place           Dive Bar              45000  41.455409 -81.700073
# 22        Diner  Convenience Store              67200  41.434653 -81.699439
# 27     Dive Bar     Discount Store              36200  41.460289 -81.729924

# %%
n=3
print(valuerange[n])
finaldf[finaldf['Cluster']==n]
# Out:
# 86000 - 86000
#     Cluster Neighborhood First   Second        Third     Fourth  \
# 21        3    Ohio City   Bar  Brewery  Coffee Shop  Gastropub
#
#                       Fifth  Median Home Value   Latitude  Longitude
# 21  New American Restaurant              86000  41.484848 -81.711744

# %%
n=4
print(valuerange[n])
finaldf[finaldf['Cluster']==n]
# Out:
# 84900 - 84900
#    Cluster Neighborhood        First Second    Third               Fourth  \
# 7        4     Downtown  Coffee Shop  Hotel  Theater  American Restaurant
#
#         Fifth  Median Home Value   Latitude  Longitude
# 7  Steakhouse              84900  41.510191 -81.686273

# %% [markdown]
# ## Secondary Analysis

# %% [markdown]
# Another approach is to use multiple linear regression.  If the target is median home values, then the input data would be the sum of each venue category for each neighborhood.  We split into train and test sets to evaluate the model.

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

andfy = zdf2['Median Home Value']
andfx = andfsum.drop('Neighborhood',1)

#andfx = andfx.drop('Median Home Values',1)

regr = linear_model.LinearRegression()
x = np.asanyarray(andfx)
y = np.asanyarray(andfy)
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.3)

regr.fit (xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# The model seems to fail

# %%
regr.score(xtest,ytest)
# Out:
# 0.19948572316652136

# %%
l =[]
for n in range(20):
    regr = linear_model.LinearRegression()
    x = np.asanyarray(andfx)
    y = np.asanyarray(andfy)
    xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.3)

    regr.fit (xtrain, ytrain)
    l.append(regr.score(xtest,ytest))
l=np.asanyarray(l)
l.mean()
# Out:
# -0.29580883361431076
